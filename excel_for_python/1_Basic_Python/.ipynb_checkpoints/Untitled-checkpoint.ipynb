# %%
import pandas as pd

# %%
df =pd.read_excel(r"C:\Users\Samsung\Desktop\test1.xlsx")
# Out:
# C:\Users\Samsung\Desktop\General\Projects\Python learning\py_venv\lib\site-packages\openpyxl\worksheet\_reader.py:211: UserWarning: Cell J929 is marked as a date but the serial value 76666374 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)

# %%
df.loc[(df['Inbound Opp#'] == 'Q-066558') ,:]
# Out:
#      Date (In/out) Movement Type                From    Bin Locatin  \
# 1994    2021-05-12             In          GZ factory  Back-to-back
# 1995    2021-05-12             In          GZ factory  Back-to-back
# 1996    2021-05-12             In          GZ factory  Back-to-back
# 1997    2021-05-12             In          GZ factory  Back-to-back
# 1998    2021-05-12            Out      Main Warehouse  Back-to-back
# 1999    2021-05-12            Out      Main Warehouse  Back-to-back
# 2000    2021-05-12            Out      Main Warehouse  Back-to-back
# 2001    2021-05-12            Out      Main Warehouse  Back-to-back
# 2010    2021-05-12             In          GZ factory  Back-to-back
# 2011    2021-05-12             In          GZ factory  Back-to-back
# 2012    2021-05-12            Out      Main Warehouse  Back-to-back
# 2013    2021-05-12            Out      Main Warehouse  Back-to-back
# 2026    2021-06-01             In          GZ factory          ONZA
# ...
